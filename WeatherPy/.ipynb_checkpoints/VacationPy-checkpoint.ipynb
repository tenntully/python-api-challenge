# %% [markdown]
# # VacationPy
# ---
# #### Jason Hanlin
# #### Data Analytics Boot Camp
# #### Python API Challenge March 7, 2023
# #### Using Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID              City      Lat       Lng  Max Temp  Humidity  \
# 0        0  verkhnyaya toyma  62.2349   44.9985    27.158        96
# 1        1    guerrero negro  27.9769 -114.0611    54.392        83
# 2        2         khvoynaya  58.9000   34.5333    23.270        88
# 3        3            atuona  -9.8000 -139.0333    79.358        79
# 4        4           college  64.8569 -147.8028    30.524        91
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        3.60      RU  1678363185
# 1          98        6.41      MX  1678363186
# 2         100        5.06      RU  1678363188
# 3           7        4.28      PF  1678363190
# 4         100        4.12      US  1678363191

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriNatGeo",
    frame_width = 700,
    frame_height = 500,
    s = "Humidity",
    scale = .8
    )

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
city_data_filtered_df = city_data_df[(city_data_df["Humidity"] < 70)]
city_data_filtered_df = city_data_filtered_df[(city_data_filtered_df["Max Temp"] < 85) & (city_data_filtered_df["Max Temp"] > 60)]
len(city_data_filtered_df)

# Drop any rows with null values
city_data_filtered_df = city_data_filtered_df.dropna()
len(city_data_filtered_df)

# Display sample data
city_data_filtered_df
# Out:
#      City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 11        11      lusambo  -4.9667   23.4500    82.562        67          99
# 34        34     necochea -38.5473  -58.7368    73.814        45          47
# 51        51   morant bay  17.8815  -76.4093    74.822        69          97
# 52        52       namibe -15.1961   12.1522    80.744        58          53
# 61        61  port alfred -33.5906   26.8910    78.188        69           0
# ..       ...          ...      ...       ...       ...       ...         ...
# 546      546       rivera -30.9053  -55.5508    82.022        47           0
# 549      549       bantou  26.2151  117.4893    66.488        50           0
# 554      554    micheweni  -4.9667   39.8333    84.254        63          48
# 557      557  bandarbeyla   9.4942   50.8122    81.410        64          50
# 561      561        khodz  44.5102   40.7142    60.314        42          95
#
#      Wind Speed Country        Date
# 11         1.72      CD  1678363201
# 34         3.85      AR  1678363271
# 51         3.09      JM  1678363297
# 52         5.47      AO  1678363298
# 61         1.34      ZA  1678363313
# ..          ...     ...         ...
# 546        1.69      UY  1678364123
# 549        1.69      CN  1678364128
# 554        6.67      TZ  1678364138
# 557        6.11      SO  1678364144
# 561        2.07      RU  1678364150
#
# [81 rows x 10 columns]

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_filtered_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""
hotel_df.head()
# Out:
#            City Country      Lat      Lng  Humidity Hotel Name
# 11      lusambo      CD  -4.9667  23.4500        67
# 34     necochea      AR -38.5473 -58.7368        45
# 51   morant bay      JM  17.8815 -76.4093        69
# 52       namibe      AO -15.1961  12.1522        58
# 61  port alfred      ZA -33.5906  26.8910        69

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
categories = "accommodation.hotel"

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    filters = f"circle:{longitude},{latitude},{radius}"
    bias = f"proximity:{longitude},{latitude}"
    
    params = {
    "categories":categories,    
    "filter":filters,
    "bias":bias,
    "apiKey":geoapify_key    
    }
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make an API request using the params dictionary
    name_address = requests.get(base_url, params=params).json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][1]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")
    

# Display sample data
hotel_df
# Out:
# Starting hotel search
# lusambo - nearest hotel: No hotel found
# necochea - nearest hotel: No hotel found
# morant bay - nearest hotel: Golden Shore Resort
# namibe - nearest hotel: Iu
# port alfred - nearest hotel: Ferryman
# heilbron - nearest hotel: No hotel found
# aswan - nearest hotel: Yassin Hotel
# upington - nearest hotel: Affinity Guesthouse
# rutigliano - nearest hotel: Una Hotel regina
# broken hill - nearest hotel: Old Royal Hotel
# mwene-ditu - nearest hotel: PLASEM SENDA MWANA
# chuy - nearest hotel: Hospedaje Atlántico
# general roca - nearest hotel: Hotel Estepa
# alice springs - nearest hotel: Todd Tavern
# matay - nearest hotel: No hotel found
# ginir - nearest hotel: No hotel found
# netarhat - nearest hotel: No hotel found
# sao filipe - nearest hotel: The Colonial Guesthouse
# cabo san lucas - nearest hotel: Real Dorada
# carnarvon - nearest hotel: No hotel found
# jalu - nearest hotel: فندق جالو السياحي
# faya - nearest hotel: No hotel found
# menongue - nearest hotel: Iu
# east london - nearest hotel: Majestic Boutique Hotel
# remigio - nearest hotel: No hotel found
# kruisfontein - nearest hotel: No hotel found
# esna - nearest hotel: No hotel found
# lamu - nearest hotel: Palace hotel
# caravelas - nearest hotel: Pousada Liberdade
# whyalla - nearest hotel: New Whyalla Hotel
# ban nahin - nearest hotel: No hotel found
# santa cruz de la palma - nearest hotel: Hotel San Telmo
# mogok - nearest hotel: Mogok hill
# port elizabeth - nearest hotel: Newtondale
# yulara - nearest hotel: Emu Walk Apartments
# mitsamiouli - nearest hotel: Maludja Bungalows
# khuzdar - nearest hotel: saudi hotel
# gat - nearest hotel: No hotel found
# nouadhibou - nearest hotel: No hotel found
# kaniama - nearest hotel: No hotel found
# mvuma - nearest hotel: No hotel found
# cidreira - nearest hotel: Lagoa Country Club
# salalah - nearest hotel: Al Andalus Hotel Apartments
# ierapetra - nearest hotel: Old town hotel
# buriti dos lopes - nearest hotel: No hotel found
# kashi - nearest hotel: Oyo Hotel
# cockburn town - nearest hotel: Turks Head Inn
# chaohu - nearest hotel: No hotel found
# gramsh - nearest hotel: Hotel Latifi
# sur - nearest hotel: Sur Hotel
# alyangula - nearest hotel: No hotel found
# buritis - nearest hotel: No hotel found
# san javier - nearest hotel: Hotel Mar Menor
# guaymas - nearest hotel: No hotel found
# rocha - nearest hotel: Hotel Arrarte
# chabahar - nearest hotel: هتل آذین
# nanzhou - nearest hotel: No hotel found
# orocue - nearest hotel: No hotel found
# buraydah - nearest hotel: شقق الجردان
# caninde - nearest hotel: No hotel found
# bardiyah - nearest hotel: No hotel found
# port blair - nearest hotel: Sinclairs Bay View
# syracuse - nearest hotel: No hotel found
# baoning - nearest hotel: No hotel found
# liling - nearest hotel: No hotel found
# tezu - nearest hotel: No hotel found
# sakakah - nearest hotel: sakakah residence
# yongchang - nearest hotel: No hotel found
# the valley - nearest hotel: Edwards Inn
# singarayakonda - nearest hotel: No hotel found
# abha - nearest hotel: OYO 324
# elliot - nearest hotel: No hotel found
# geraldton - nearest hotel: The Gerald Apartment Hotel
# zabol - nearest hotel: No hotel found
# abu samrah - nearest hotel: No hotel found
# viedma - nearest hotel: Residencial roca
# rivera - nearest hotel: No hotel found
# bantou - nearest hotel: No hotel found
# micheweni - nearest hotel: No hotel found
# bandarbeyla - nearest hotel: No hotel found
# khodz - nearest hotel: No hotel found
#             City Country      Lat       Lng  Humidity           Hotel Name
# 11       lusambo      CD  -4.9667   23.4500        67       No hotel found
# 34      necochea      AR -38.5473  -58.7368        45       No hotel found
# 51    morant bay      JM  17.8815  -76.4093        69  Golden Shore Resort
# 52        namibe      AO -15.1961   12.1522        58                   Iu
# 61   port alfred      ZA -33.5906   26.8910        69             Ferryman
# ..           ...     ...      ...       ...       ...                  ...
# 546       rivera      UY -30.9053  -55.5508        47       No hotel found
# 549       bantou      CN  26.2151  117.4893        50       No hotel found
# 554    micheweni      TZ  -4.9667   39.8333        63       No hotel found
# 557  bandarbeyla      SO   9.4942   50.8122        64       No hotel found
# 561        khodz      RU  44.5102   40.7142        42       No hotel found
#
# [81 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriNatGeo",
    frame_width = 700,
    frame_height = 500,
    s = "Humidity",
    scale = 1.2,
    hover_cols = ["City", "Country", "Hotel Name"]
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity,City,Country,Hotel Name)
